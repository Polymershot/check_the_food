# %% [markdown]
# # Model Building

# %% [markdown]
# ## Load the Data

# %%
import pandas as pd

df = pd.read_csv('../data/combined_food_data.csv', index_col=False)
print(df.shape)
df.head()
# Out:
# (37156, 13)
#    novaclass   Protein  Total Fat  Carbohydrate  Sugars, total  \
# 0        4.0  2.897568   3.459152      1.308333       0.815365
# 1        4.0  3.096934   3.440418      0.548121      -0.478036
# 2        4.0  3.208017   3.219276      0.741937       0.207014
# 3        4.0  2.824944   3.243764      2.147100       1.720979
# 4        4.0  2.797891   3.055415      2.166765       1.990610
#
#    Fiber, total dietary   Calcium      Iron    Sodium  Vitamin C  Cholesterol  \
# 0            -20.000000  0.044017 -7.369791  0.513422 -20.000000    -2.302585
# 1             -2.302585 -0.487760 -7.775256  0.356275  -6.074846    -2.364460
# 2            -20.000000 -0.258771 -7.402052  0.314811 -20.000000    -2.465104
# 3            -20.000000 -0.382726 -8.254829  0.249980 -20.000000    -2.322788
# 4            -20.000000 -0.576253 -8.016418  0.485508 -20.000000    -2.900422
#
#    Fatty acids, total saturated  Total Vitamin A
# 0                      2.893533        -8.037858
# 1                      2.978739        -7.841701
# 2                      2.775397        -8.274247
# 3                      2.711843        -8.250990
# 4                      2.589792        -8.408339

# %% [markdown]
# ## Preprocessing

# %%
df['novaclass'].value_counts()
# Out:
# novaclass
# 3.0    22116
# 4.0     4972
# 1.0     4009
# 0.0     3327
# 2.0     2732
# Name: count, dtype: int64

# %% [markdown]
# A novaclass score of 3 means that most of the foods in the dataset can be considered "processed".

# %%
# Create input and output variables
x = df.iloc[:, -12:]
y = df.iloc[:, 0]
print('X Variables:', '\n', x.head(), "\n")
print('Y Variable:', '\n', y.head())
# Out:
# X Variables:
#      Protein  Total Fat  Carbohydrate  Sugars, total  Fiber, total dietary  \
# 0  2.897568   3.459152      1.308333       0.815365            -20.000000
# 1  3.096934   3.440418      0.548121      -0.478036             -2.302585
# 2  3.208017   3.219276      0.741937       0.207014            -20.000000
# 3  2.824944   3.243764      2.147100       1.720979            -20.000000
# 4  2.797891   3.055415      2.166765       1.990610            -20.000000
#
#     Calcium      Iron    Sodium  Vitamin C  Cholesterol  \
# 0  0.044017 -7.369791  0.513422 -20.000000    -2.302585
# 1 -0.487760 -7.775256  0.356275  -6.074846    -2.364460
# 2 -0.258771 -7.402052  0.314811 -20.000000    -2.465104
# 3 -0.382726 -8.254829  0.249980 -20.000000    -2.322788
# 4 -0.576253 -8.016418  0.485508 -20.000000    -2.900422
#
#    Fatty acids, total saturated  Total Vitamin A
# 0                      2.893533        -8.037858
# 1                      2.978739        -7.841701
# 2                      2.775397        -8.274247
# 3                      2.711843        -8.250990
# 4                      2.589792        -8.408339
#
# Y Variable:
#  0    4.0
# 1    4.0
# 2    4.0
# 3    4.0
# 4    4.0
# Name: novaclass, dtype: float64

# %% [markdown]
# ## Data Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, stratify=y) 
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (29724, 12)
# (7432, 12)
# (29724,)
# (7432,)

# %% [markdown]
# A 0.8-0.2 split will be considered for now unless model performance after the RandomizedSearch is horrible.

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# We should be equally worried about false positives and false negatives since the dependent variable has to do with how "processed" a food is. Two considerations for evaluating the models would be some sort of balanced/weighted metric, or the macro-f1 metric.

# %%
from sklearn.model_selection import RandomizedSearchCV
from imblearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression

# Import helper function from another directory
import sys
sys.path.append('../')
from src.model_building_evaluation_functions import *

# Hyperparameter tuning 
random_search_table = randomized_search_loop(X_train, y_train)
random_search_table.head(20)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 29     121.918373      0.705720         0.436681        0.010398
# 22      33.012928      1.954902         0.340872        0.138236
# 25      35.767279      1.805044         0.250696        0.122465
# 17     112.691896      2.672836         0.817392        0.146977
# 13     141.906588      2.500055         0.551629        0.024821
# 3        6.068406      0.106553         0.122392        0.003398
# 24       5.128696      0.750954         0.125472        0.022095
# 10       5.194046      0.334526         0.103094        0.021840
# 23       4.281168      0.186170         0.085475        0.004186
# 16       5.296919      0.413700         0.106736        0.012173
# 2        5.686767      0.382776         0.130630        0.030939
# 5        3.392242      0.368720         0.032211        0.006287
# 21       3.005903      0.279658         0.027146        0.005517
# 9        4.804266      0.565284         0.027924        0.005429
# 19       4.005679      0.318234         0.078249        0.001041
# 15       7.336481      0.698260         0.229185        0.039640
# 12       4.833544      0.708564         0.097936        0.011663
# 1        5.045289      0.505473         0.111352        0.015526
# 14       5.721432      0.115193         0.139107        0.030877
# 27       5.453382      0.813773         0.139676        0.025617
#
#     param_model__n_estimators param_model__max_depth param_model__criterion  \
# 29                      500.0                     50                entropy
# 22                      100.0                   None               log_loss
# 25                      100.0                     50                entropy
# 17                      500.0                   None                   gini
# 13                      500.0                   None               log_loss
# 3                         NaN                     10                    NaN
# 24                        NaN                     10                    NaN
# 10                        NaN                     10                    NaN
# 23                        NaN                      6                    NaN
# 16                        NaN                     10                    NaN
# 2                         NaN                      6                    NaN
# 5                        10.0                     50                   gini
# 21                       10.0                   None                   gini
# 9                        10.0                   None                entropy
# 19                        NaN                     10                    NaN
# 15                        NaN                     10                    NaN
# 12                        NaN                     10                    NaN
# 1                         NaN                      6                    NaN
# 14                        NaN                      6                    NaN
# 27                        NaN                      6                    NaN
#
#                                           param_model  param_model__gamma  \
# 29                           RandomForestClassifier()                 NaN
# 22                           RandomForestClassifier()                 NaN
# 25                           RandomForestClassifier()                 NaN
# 17                           RandomForestClassifier()                 NaN
# 13                           RandomForestClassifier()                 NaN
# 3   XGBClassifier(base_score=None, booster=None, c...                 0.1
# 24  XGBClassifier(base_score=None, booster=None, c...                 0.3
# 10  XGBClassifier(base_score=None, booster=None, c...                 0.1
# 23  XGBClassifier(base_score=None, booster=None, c...                 0.1
# 16  XGBClassifier(base_score=None, booster=None, c...                 0.3
# 2   XGBClassifier(base_score=None, booster=None, c...                 0.3
# 5                            RandomForestClassifier()                 NaN
# 21                           RandomForestClassifier()                 NaN
# 9                            RandomForestClassifier()                 NaN
# 19  XGBClassifier(base_score=None, booster=None, c...                 1.0
# 15  XGBClassifier(base_score=None, booster=None, c...                 1.0
# 12  XGBClassifier(base_score=None, booster=None, c...                 1.0
# 1   XGBClassifier(base_score=None, booster=None, c...                 1.0
# 14  XGBClassifier(base_score=None, booster=None, c...                 1.0
# 27  XGBClassifier(base_score=None, booster=None, c...                 1.0
#
#     param_model__eta  param_model__alpha  \
# 29               NaN                 NaN
# 22               NaN                 NaN
# 25               NaN                 NaN
# 17               NaN                 NaN
# 13               NaN                 NaN
# 3                0.3                 1.0
# 24               0.3                 0.0
# 10               0.5                 1.0
# 23               0.5                 1.0
# 16               0.3                 1.0
# 2                0.3                 0.0
# 5                NaN                 NaN
# 21               NaN                 NaN
# 9                NaN                 NaN
# 19               0.3                 0.0
# 15               0.1                 1.0
# 12               0.3                 1.0
# 1                0.3                 0.0
# 14               0.1                 0.0
# 27               0.1                 1.0
#
#                                                params  split0_test_score  \
# 29  {'model__n_estimators': 500, 'model__max_depth...           0.945264
# 22  {'model__n_estimators': 100, 'model__max_depth...           0.943405
# 25  {'model__n_estimators': 100, 'model__max_depth...           0.943536
# 17  {'model__n_estimators': 500, 'model__max_depth...           0.943188
# 13  {'model__n_estimators': 500, 'model__max_depth...           0.944489
# 3   {'model__max_depth': 10, 'model__gamma': 0.1, ...           0.938510
# 24  {'model__max_depth': 10, 'model__gamma': 0.3, ...           0.939770
# 10  {'model__max_depth': 10, 'model__gamma': 0.1, ...           0.936320
# 23  {'model__max_depth': 6, 'model__gamma': 0.1, '...           0.935481
# 16  {'model__max_depth': 10, 'model__gamma': 0.3, ...           0.931872
# 2   {'model__max_depth': 6, 'model__gamma': 0.3, '...           0.928293
# 5   {'model__n_estimators': 10, 'model__max_depth'...           0.929597
# 21  {'model__n_estimators': 10, 'model__max_depth'...           0.930293
# 9   {'model__n_estimators': 10, 'model__max_depth'...           0.930546
# 19  {'model__max_depth': 10, 'model__gamma': 1, 'm...           0.925681
# 15  {'model__max_depth': 10, 'model__gamma': 1, 'm...           0.925206
# 12  {'model__max_depth': 10, 'model__gamma': 1, 'm...           0.927391
# 1   {'model__max_depth': 6, 'model__gamma': 1, 'mo...           0.913362
# 14  {'model__max_depth': 6, 'model__gamma': 1, 'mo...           0.899480
# 27  {'model__max_depth': 6, 'model__gamma': 1, 'mo...           0.893952
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 29           0.941802           0.937966         0.941677        0.002981
# 22           0.941933           0.937924         0.941087        0.002316
# 25           0.941734           0.936936         0.940735        0.002786
# 17           0.941503           0.937433         0.940708        0.002416
# 13           0.940092           0.935143         0.939908        0.003818
# 3            0.933439           0.936574         0.936174        0.002090
# 24           0.935272           0.932372         0.935805        0.003043
# 10           0.935104           0.934648         0.935357        0.000706
# 23           0.935738           0.932567         0.934595        0.001438
# 16           0.933907           0.927895         0.931225        0.002497
# 2            0.933487           0.926805         0.929528        0.002865
# 5            0.930626           0.925342         0.928522        0.002287
# 21           0.927263           0.923702         0.927086        0.002694
# 9            0.924534           0.922545         0.925875        0.003401
# 19           0.927075           0.922918         0.925225        0.001728
# 15           0.923681           0.919986         0.922958        0.002192
# 12           0.921880           0.919541         0.922937        0.003291
# 1            0.914358           0.913321         0.913680        0.000479
# 14           0.892278           0.891014         0.894257        0.003729
# 27           0.893425           0.890277         0.892551        0.001622
#
#     rank_test_score
# 29                1
# 22                2
# 25                3
# 17                4
# 13                5
# 3                 6
# 24                7
# 10                8
# 23                9
# 16               10
# 2                11
# 5                12
# 21               13
# 9                14
# 19               15
# 15               16
# 12               17
# 1                18
# 14               19
# 27               20

# %% [markdown]
# Hyperparameters and Smote did not do much in terms of improving the f1-macro score. Let's just use a default RandomForest model with 100 trees for safe measures.

# %% [markdown]
# ## Retraining and Evaluating Final Model

# %%
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# Test data
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),  # true --> sum of true values (rowwise total sum)
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        rf_model,
        X_test,
        y_test,
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)
    fig = disp.figure_
    fig.set_figwidth(10)
    fig.set_figheight(10) 
plt.show()



# F1-score
y_pred = rf_model.predict(X_test)
print('\n', 'Classification Report:', '\n', classification_report(y_test, y_pred, digits = 4))
# Out:
#  Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.9543    0.9429    0.9486       665
#          1.0     0.9524    0.9227    0.9373       802
#          2.0     0.9406    0.8407    0.8878       546
#          3.0     0.9688    0.9889    0.9787      4424
#          4.0     0.9557    0.9548    0.9553       995
#
#     accuracy                         0.9622      7432
#    macro avg     0.9544    0.9300    0.9415      7432
# weighted avg     0.9619    0.9622    0.9617      7432
